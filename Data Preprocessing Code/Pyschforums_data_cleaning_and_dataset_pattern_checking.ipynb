# %%
import requests
from bs4 import BeautifulSoup
import time
import hashlib
import os
import json
from urllib.parse import urljoin

# ==== CONFIGURATION ====
BASE_URL = "https://www.psychforums.com"
OUTPUT_FILE = "psychforums_dataset_2.jsonl"
PAGES_PER_SUBFORUM = 5
REQUEST_DELAY = 1  # seconds

# PLACEHOLDER — paste the exact sub-forum URLs you want to scrape here:
SUBFORUM_URLS = [
    "https://www.psychforums.com/food-addiction/",
    "https://www.psychforums.com/narcissistic-personality/",
    "https://www.psychforums.com/delusional-disorder/",
    "https://www.psychforums.com/alzheimer/",
    "https://www.psychforums.com/domestic-abuse/",
    
    # Add more here...
]

# ==== UTILITIES ====
def clean_text(text):
    return ' '.join(text.split())

def text_hash(text):
    return hashlib.sha256(text.encode("utf-8")).hexdigest()

def save_jsonl(data, filename):
    with open(filename, "a", encoding="utf-8") as f:
        f.write(json.dumps(data, ensure_ascii=False) + "\n")

def fetch(url):
    try:
        r = requests.get(url, timeout=15)
        r.raise_for_status()
        return r.text
    except Exception as e:
        print(f"[Error] Failed to fetch {url}: {e}")
        return None

# ==== SCRAPING ====
def scrape_thread(thread_url):
    html = fetch(thread_url)
    if not html:
        return None

    soup = BeautifulSoup(html, "html.parser")
    posts = []

    for post in soup.select(".postbody"):
        content = clean_text(post.get_text(separator=" ", strip=True))
        if content:
            posts.append(content)

    return posts

def scrape_subforum(subforum_url):
    for page in range(0, PAGES_PER_SUBFORUM):
        offset = page * 40
        url = subforum_url if page == 0 else urljoin(subforum_url, f"page{offset}.html")
        html = fetch(url)
        if not html:
            continue

        soup = BeautifulSoup(html, "html.parser")
        threads = soup.select("a.topictitle")

        if not threads:
            print(f"[{subforum_url}] No threads found on page {page+1}")
            break

        for t in threads:
            thread_href = t.get("href")
            thread_url = urljoin(BASE_URL, thread_href)
            print(f"  -> Scraping thread: {thread_url}")

            posts = scrape_thread(thread_url)
            if posts:
                for p in posts:
                    record = {
                        "url": thread_url,
                        "text": p,
                        "hash": text_hash(p)
                    }
                    save_jsonl(record, OUTPUT_FILE)

        time.sleep(REQUEST_DELAY)

# ==== MAIN ====
if __name__ == "__main__":
    if os.path.exists(OUTPUT_FILE):
        os.remove(OUTPUT_FILE)

    for subforum in SUBFORUM_URLS:
        print(f"Scraping sub-forum: {subforum}")
        scrape_subforum(subforum)

    print(f"Scraping complete. Data saved to {OUTPUT_FILE}")
# Out:
# Scraping sub-forum: https://www.psychforums.com/food-addiction/
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic126438.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic198674.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic156051.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic217018.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic215555.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic215416.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic205446.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic90784.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic210417.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic207413.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic200427.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic205211.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic197615.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic197611.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic196094.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic196033.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic86253.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic191785.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic194587.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic194036.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic186640.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic191714.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic189643.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic83732.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic62781.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic175362.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic140333.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic142468.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic158170.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic84700.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic170022.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic142127.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic158341.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic154625.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic142245.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic143826.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic152896.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic154381.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic146064.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic140458.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic140006.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic137394.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic135503.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic134838.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic135674.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic134631.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic132287.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic128767.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic109482.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic124028.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic97059.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic123329.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic123266.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic123457.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic51509.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic120958.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic108374.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic99373.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic106924.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic86525.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic96768.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic95554.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic97238.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic90956.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic86975.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic84715.html
#   -> Scraping thread: https://www.psychforums.com:443/internet-addiction/topic86633.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic50924.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic74911.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic69909.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic56459.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic76967.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic77114.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic43247.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic67663.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic73080.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic73018.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic69603.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic47776.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic52795.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic64354.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic50421.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic54695.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic64354.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic50421.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic54695.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic64354.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic50421.html
#   -> Scraping thread: https://www.psychforums.com:443/food-addiction/topic54695.html
# Scraping sub-forum: https://www.psychforums.com/narcissistic-personality/
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic2000.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic119161.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic34742.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic202431.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic202429.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic14021.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic85447.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic42637.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic223448.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221473.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic222231.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic178081.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic224847.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic224049.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic224331.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic222329.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic222676.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic222277.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic222478.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic222230.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic149482.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221273.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic222164.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic181247.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221965.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221759.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221603.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic219041.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221457.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221333.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221329.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220907.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220648.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220416.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221045.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic221041.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220746.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220530.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220879.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220458.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic122727.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217317.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220345.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic218733.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220376.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic219973.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic219483.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic116470.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217979.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic220023.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic207795.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic219687.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic156417.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic219192.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic218690.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217005.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217498.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217322.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217947.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217616.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217600.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217549.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216161.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217448.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217321.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217306.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217273.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217181.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217190.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217263.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217241.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215801.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217261.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217249.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217233.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217258.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217187.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217247.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217228.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216813.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216867.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217224.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217221.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216716.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217171.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217004.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217216.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215998.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217207.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216173.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217206.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216924.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216875.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216773.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic207705.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217167.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216941.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215716.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic217060.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216959.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216806.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216943.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216910.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216899.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216840.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216668.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215286.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216763.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216688.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215824.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216655.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216661.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216592.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216611.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214673.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216506.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216571.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216562.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215990.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216574.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216570.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216496.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216519.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216306.html
#   -> Scraping thread: https://www.psychforums.com:443/family-support/topic216486.html
#   -> Scraping thread: https://www.psychforums.com:443/family-support/topic216480.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215904.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216502.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216166.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic213019.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216322.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216228.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215823.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic216040.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215735.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215899.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215928.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215912.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215454.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214730.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215756.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214017.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215728.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215426.html
#   -> Scraping thread: https://www.psychforums.com:443/family-support/topic215623.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215499.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215478.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215399.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215427.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215461.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214306.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215414.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215296.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215193.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215389.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214990.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215402.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215371.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215391.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215164.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215356.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214849.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic210126.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215246.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215313.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215230.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215255.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215303.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214404.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215093.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215229.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215212.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214898.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214806.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214824.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic215106.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214483.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214687.html
#   -> Scraping thread: https://www.psychforums.com:443/relationship/topic214874.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214573.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214676.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214187.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214465.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214522.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214321.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic202086.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214180.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214355.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214034.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214035.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214129.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic194509.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214282.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic212948.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic213986.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic213916.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214090.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic64338.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic214006.html
#   -> Scraping thread: https://www.psychforums.com:443/narcissistic-personality/topic213920.html
# Scraping sub-forum: https://www.psychforums.com/delusional-disorder/
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1281.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1101.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic225572.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic225535.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic218648.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic28336.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic223840.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic221976.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic224132.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic224066.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic223359.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic223061.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic222785.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic222917.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic222400.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic222357.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic221858.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic220347.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic220071.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic221520.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic221439.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic221233.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic221227.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic221006.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic220867.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic220365.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic220148.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic218694.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic220164.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic219896.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic219294.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic218919.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic219765.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic219581.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic219519.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic219337.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic219114.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic219018.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic218813.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic218189.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic216417.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic218244.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1281.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1101.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic214328.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic217272.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic217850.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic217871.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic217832.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic217644.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207647.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic217438.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic217007.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic214793.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic215217.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic217077.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic216194.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic215502.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic216093.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic216076.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic215311.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic214517.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic211191.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic213589.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic214577.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic209032.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic184101.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic206022.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic214342.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212883.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic75072.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212871.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212499.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic213052.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic213150.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic210119.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212970.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212870.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212656.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212201.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212615.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212601.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212263.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic212148.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1281.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1101.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic210716.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic43326.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic210369.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic210844.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic55682.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic210439.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207359.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic210022.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic209287.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic209731.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic209548.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic209470.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204887.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic209266.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic208615.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic208994.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204344.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic208691.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic208810.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic208267.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207600.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic208651.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic208605.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic31547.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic208171.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207310.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207578.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207348.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207125.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204291.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic122930.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207015.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic207039.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic206900.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic206869.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic205994.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic206418.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic88742.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic205856.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic205800.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1281.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1101.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic205473.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic205138.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204879.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic205031.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204958.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204640.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204722.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204368.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic197753.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic200848.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic204169.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic203709.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic201069.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic203397.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic203107.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic201072.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic197105.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic202641.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic202900.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic202837.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic202819.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic202549.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic201993.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic201114.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic201148.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic200029.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic200489.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic181936.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic199890.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic199457.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic199838.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic199644.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic198631.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic198576.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic197814.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic198120.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic197892.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic187443.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic197280.html
#   -> Scraping thread: https://www.psychforums.com:443/family-support/topic197243.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1281.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic1101.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic196363.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic196015.html
#   -> Scraping thread: https://www.psychforums.com:443/family-support/topic196642.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic196475.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic194860.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic196291.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic196114.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic195888.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic195876.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic18356.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic168647.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic182500.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic195510.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic195442.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic194686.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic192588.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic184693.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic192458.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic193577.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic185256.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic193516.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic193884.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic192544.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic192726.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic189849.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic193423.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic57649.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic192635.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic192400.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic186187.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic192140.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic191796.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic191505.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic191196.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic188602.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic189893.html
#   -> Scraping thread: https://www.psychforums.com:443/family-support/topic189836.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic185173.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic186102.html
#   -> Scraping thread: https://www.psychforums.com:443/delusional-disorder/topic188474.html
# Scraping sub-forum: https://www.psychforums.com/alzheimer/
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic217726.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic210883.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic207485.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic205181.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic201436.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic28212.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic167392.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic21706.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic133386.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic58121.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic89734.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic17356.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic27464.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic65437.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic92245.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic113122.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic115579.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic52301.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic97445.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic43433.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic6466.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic93781.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic31422.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic8024.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic47396.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic62632.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic54545.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic19958.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic50433.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic10207.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic58978.html
# [Error] Failed to fetch https://www.psychforums.com:443/alzheimer/topic58978.html: HTTPSConnectionPool(host='www.psychforums.com', port=443): Max retries exceeded with url: /alzheimer/topic58978.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11c2e9a90>, 'Connection to www.psychforums.com timed out. (connect timeout=15)'))
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic54618.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic9484.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic44950.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic44043.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic43931.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic42047.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic41469.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic25738.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic18303.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic23848.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic17814.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic10443.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic8077.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic7639.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic7457.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic6202.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic17.html
#   -> Scraping thread: https://www.psychforums.com:443/announces/topic43798.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic23848.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic17814.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic10443.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic8077.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic7639.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic7457.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic6202.html
#   -> Scraping thread: https://www.psychforums.com:443/alzheimer/topic17.html
# [Error] Failed to fetch https://www.psychforums.com:443/alzheimer/topic17.html: HTTPSConnectionPool(host='www.psychforums.com', port=443): Max retries exceeded with url: /alzheimer/topic17.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11c6c73b0>, 'Connection to www.psychforums.com timed out. (connect timeout=15)'))
# [Error] Failed to fetch https://www.psychforums.com/alzheimer/page120.html: HTTPSConnectionPool(host='www.psychforums.com', port=443): Max retries exceeded with url: /alzheimer/page120.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x11c6c7e60>, 'Connection to www.psychforums.com timed out. (connect timeout=15)'))
# [https://www.psychforums.com/alzheimer/] No threads found on page 5
# Scraping sub-forum: https://www.psychforums.com/domestic-abuse/
# [https://www.psychforums.com/domestic-abuse/] No threads found on page 1
# Scraping complete. Data saved to psychforums_dataset_2.jsonl

# %%
import re
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# ---------- CONFIG ----------
INPUT_FILE = "psychforums_dataset_cleaned.csv"     # CSV file with a 'text' column
OUTPUT_FILE = "psychforums_dataset_cleaned_1.csv"
SIMILARITY_THRESHOLD = 0.9     # For near-duplicate removal
MIN_WORDS = 5                  # Minimum words to keep a post

# Common boilerplate phrases to remove
BOILERPLATE_PATTERNS = [
    r"forum rules", r"active staff list", r"moderator", r"admins?",
    r"we do not delete posts", r"privacy policy", r"copyright notice",
    r"disclaimer", r"report posts", r"shadow.*post", r"member corne",
    r"index page", r"complaints", r"contact another mod", r"volunteers"
]

# Words that indicate personal expression (keeps human conversation)
HUMAN_KEYWORDS = [
    "i ", "i'm", "i’ve", "my ", "me ", "mine", "myself",
    "feel", "anxious", "anxiety", "worried", "happy", "sad",
    "angry", "upset", "excited", "love", "hate"
]

# ---------- LOAD DATA ----------
df = pd.read_csv(INPUT_FILE)
if 'text' not in df.columns:
    raise ValueError("CSV must have a 'text' column.")

# Lowercase and strip whitespace
df['text'] = df['text'].astype(str).str.strip().str.lower()

# ---------- REMOVE BOILERPLATE ----------
def contains_boilerplate(text):
    return any(re.search(pat, text) for pat in BOILERPLATE_PATTERNS)

df = df[~df['text'].apply(contains_boilerplate)]

# ---------- REMOVE SHORT POSTS ----------
df = df[df['text'].apply(lambda x: len(x.split()) >= MIN_WORDS)]

# ---------- KEEP HUMAN CONVERSATION ----------
def looks_human(text):
    return any(kw in text for kw in HUMAN_KEYWORDS)

df = df[df['text'].apply(looks_human)]

# ---------- REMOVE NEAR-DUPLICATES ----------
vectorizer = TfidfVectorizer().fit_transform(df['text'])
similarity_matrix = cosine_similarity(vectorizer)

# Mark duplicates
to_drop = set()
for i in range(len(similarity_matrix)):
    if i in to_drop:
        continue
    for j in range(i+1, len(similarity_matrix)):
        if similarity_matrix[i, j] > SIMILARITY_THRESHOLD:
            to_drop.add(j)

df_cleaned = df.drop(df.index[list(to_drop)]).reset_index(drop=True)

# ---------- SAVE CLEANED DATA ----------
df_cleaned.to_csv(OUTPUT_FILE, index=False)
print(f"Cleaned dataset saved to {OUTPUT_FILE} with {len(df_cleaned)} examples.")
# Out:
# Cleaned dataset saved to psychforums_dataset_cleaned_1.csv with 2600 examples.

# %%
#!/usr/bin/env python3
"""
clean_to_csv.py

Usage:
    python clean_to_csv.py --input scraped.jsonl --output cleaned.csv --min-words 50

Supports input JSONL (lines of JSON) or CSV. Produces a CSV with a single column "text".
"""

import re
import argparse
import pandas as pd
import hashlib
from tqdm import tqdm

INPUT_FILE = "psychforums_dataset_2.jsonl"   # Path to your scraped dataset (JSONL or CSV)
OUTPUT_FILE = "psychforums_dataset_cleaned_2.csv"    # Path to save cleaned CSV
MIN_WORDS = 50                 # Minimum words required to keep a post
REMOVE_DUPLICATES = True       # True to drop duplicate cleaned texts
SHOW_STATS = True      

# ---------------- Helpers ----------------
def load_input(path):
    return pd.read_json(path, lines=True)

def sha1(s: str) -> str:
    return hashlib.sha1(s.encode("utf-8")).hexdigest()

# Multi-pass cleaner targeting the common forum metadata patterns
# NOTE: tweak MIN_WORDS below if you want stricter/looser filtering.
DAY_NAMES = r'(?:Mon|Tue|Wed|Thu|Fri|Sat|Sun|Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday)'
MONTH_NAMES = r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec|January|February|March|April|May|June|July|August|September|October|November|December)'

# pattern that matches: by <username> » Wed Dec 24, 2008 12:06 am (very common)
PAT_BY_DATE = re.compile(
    rf'\bby\s+[^\»\n]{{1,80}}\s*»\s*{DAY_NAMES}.*?\d{{4}}\s*(?:\d{{1,2}}:\d{{2}}\s*(?:am|pm)?)?',
    flags=re.IGNORECASE
)

# fallback: remove 'by <username> »' even if date not present
PAT_BY_SIMPLE = re.compile(r'\bby\s+[^\»\n]{1,80}\s*»\s*', flags=re.IGNORECASE)

# remove "Posted: Wed Dec 24, 2008 12:06 am" style
PAT_POSTED = re.compile(r'Posted\s*(?:on|:)?\s*.*?\d{4}.*?(?=\s[A-Z]|\n|$)', flags=re.IGNORECASE)

# remove signatures like "-- Name" or "— Name"
PAT_SIGN = re.compile(r'(^|\n)[\-\u2013\u2014]{2,}\s*\w.*', flags=re.MULTILINE)

# remove common boilerplate tokens
BOILERPLATE_LOWER = {"advertisement", "advertisements", "ad"}

def clean_post(text: str) -> str:
    if not isinstance(text, str):
        return ""

    s = text.strip()

    # quick drop for obvious boilerplate-only lines
    if s.strip().lower() in BOILERPLATE_LOWER:
        return ""

    # 1) remove explicit "by ... » <weekday> <month> <day>, <year> <time>" patterns
    s = PAT_BY_DATE.sub('', s)

    # 2) fallback: remove "by <username> »" if any remains
    s = PAT_BY_SIMPLE.sub('', s)

    # 3) remove Posted: ... patterns
    s = PAT_POSTED.sub('', s)

    # 4) remove signature separators and trailing signatures (naive)
    s = PAT_SIGN.sub('', s)

    # 5) collapse multiple whitespace/newlines into single space
    s = re.sub(r'\s+', ' ', s).strip()

    # final safety: if content reduced to short or empty, return empty
    return s

# ---------------- Main ----------------
def main():
    df = load_input(INPUT_FILE)

    if "text" not in df.columns:
        raise SystemExit("Input file must have a 'text' column")

    texts = df['text'].astype(str).tolist()
    cleaned = []
    for t in tqdm(texts, desc="Cleaning posts"):
        c = clean_post(t)
        if not c:
            continue
        # count words
        wc = len(c.split())
        if wc < MIN_WORDS:
            continue
        cleaned.append(c)

    if REMOVE_DUPLICATES:
        # preserve order but drop duplicates
        seen = set()
        uniq = []
        for s in cleaned:
            h = sha1(s)
            if h in seen:
                continue
            seen.add(h)
            uniq.append(s)
        cleaned = uniq

    # save as CSV with single column 'text'
    out_df = pd.DataFrame({"text": cleaned})
    out_df.to_csv(OUTPUT_FILE, index=False, encoding="utf-8")

    if SHOW_STATS:
        print(f"Input rows : {len(texts)}")
        print(f"Kept rows  : {len(cleaned)}")
        if REMOVE_DUPLICATES:
            print("(duplicates removed)")

if __name__ == "__main__":
    main()
# Out:
# Cleaning posts: 100%|████████████████████████| 3235/3235 [00:00<00:00, 14175.16it/s]
# Input rows : 3235
# Kept rows  : 2072
# (duplicates removed)

# %%
import re
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# ---------- CONFIG ----------
INPUT_FILE = "psychforums_dataset_cleaned_1.csv"   # CSV file with 'text' column
SIMILARITY_THRESHOLD = 0.9   # for near-duplicate detection
BOILERPLATE_PATTERNS = [
    r"forum rules", r"active staff list", r"moderator", r"admins?",
    r"we do not delete posts", r"privacy policy", r"copyright notice",
    r"disclaimer", r"report posts", r"shadow.*post", r"member corne",
    r"index page", r"complaints", r"contact another mod", r"volunteers"
]

# ---------- LOAD ----------
df = pd.read_csv(INPUT_FILE)
if 'text' not in df.columns:
    raise ValueError("CSV must have a 'text' column.")

texts = df['text'].astype(str).str.strip().str.lower()

# ---------- DUPLICATE CHECK ----------
# Exact duplicates
exact_dupes = texts.duplicated().sum()
exact_dupe_ratio = exact_dupes / len(texts) * 100

# Near duplicates
vectorizer = TfidfVectorizer().fit_transform(texts)
sim_matrix = cosine_similarity(vectorizer)
to_drop = set()
for i in range(len(sim_matrix)):
    if i in to_drop:
        continue
    for j in range(i+1, len(sim_matrix)):
        if sim_matrix[i, j] > SIMILARITY_THRESHOLD:
            to_drop.add(j)
near_dupes = len(to_drop)
near_dupe_ratio = near_dupes / len(texts) * 100

# ---------- BOILERPLATE CHECK ----------
def contains_boilerplate(text):
    return any(re.search(pat, text) for pat in BOILERPLATE_PATTERNS)

boilerplate_count = sum(contains_boilerplate(t) for t in texts)
boilerplate_ratio = boilerplate_count / len(texts) * 100

# ---------- LEXICAL DIVERSITY ----------
all_words = " ".join(texts).split()
unique_words = set(all_words)
lexical_diversity = len(unique_words) / len(all_words)

# ---------- WORD COUNT STATS ----------
word_counts = [len(t.split()) for t in texts]
avg_wc = np.mean(word_counts)
median_wc = np.median(word_counts)
short_posts = sum(wc < 5 for wc in word_counts)

# ---------- COMMON PHRASES ----------
def get_ngrams(tokens, n=3):
    return zip(*[tokens[i:] for i in range(n)])

all_tokens = " ".join(texts).split()
ngram_counts = Counter(get_ngrams(all_tokens, n=3))
common_phrases = [" ".join(k) for k, _ in ngram_counts.most_common(10)]

# ---------- REPORT ----------
print("\n===== DATA QUALITY REPORT =====")
print(f"Total examples: {len(texts)}")
print(f"Exact duplicates: {exact_dupes} ({exact_dupe_ratio:.2f}%)")
print(f"Near duplicates (> {SIMILARITY_THRESHOLD}): {near_dupes} ({near_dupe_ratio:.2f}%)")
print(f"Boilerplate matches: {boilerplate_count} ({boilerplate_ratio:.2f}%)")
print(f"Lexical diversity (type-token ratio): {lexical_diversity:.4f}")
print(f"Average word count: {avg_wc:.2f}")
print(f"Median word count: {median_wc}")
print(f"Posts with <5 words: {short_posts} ({short_posts/len(texts)*100:.2f}%)")
print("\nMost common 3-word phrases:")
for phrase in common_phrases:
    print("  -", phrase)
print("================================\n")
# Out:
# ===== DATA QUALITY REPORT =====
# Total examples: 2599
# Exact duplicates: 0 (0.00%)
# Near duplicates (> 0.9): 0 (0.00%)
# Boilerplate matches: 0 (0.00%)
# Lexical diversity (type-token ratio): 0.0613
# Average word count: 247.01
# Median word count: 161.0
# Posts with <5 words: 0 (0.00%)
#
# Most common 3-word phrases:
#   - a lot of
#   - i don't know
#   - i have a
#   - i have been
#   - i want to
#   - i am not
#   - i feel like
#   - be able to
#   - when i was
#   - i don't think
# ================================

# %%
import pandas as pd

df = pd.read_csv('Datasets/journal_reddit_posts_multilabel.csv')

# df has 'text' and 'label' columns
common_phrases = ["i feel like", "i wanted to", "i don't know", "a lot of", "i have a", "i have been", "i want to", "i am not", "be able to", "when i was", "i don't think"]
for phrase in common_phrases:
    subset = df[df['text'].str.contains(phrase, case=False)]
    print(f"Phrase: {phrase}")
    print(subset['label_0'].value_counts(normalize=True))
    print(subset['label_1'].value_counts(normalize=True))
    print(subset['label_2'].value_counts(normalize=True))
    print(subset['label_3'].value_counts(normalize=True))
    print()
# Out:
# Phrase: i feel like
# label_0
# 0    0.912186
# 1    0.087814
# Name: proportion, dtype: float64
# label_1
# 1    0.696325
# 0    0.303675
# Name: proportion, dtype: float64
# label_2
# 1    0.709091
# 0    0.290909
# Name: proportion, dtype: float64
# label_3
# 1    0.659188
# 0    0.340812
# Name: proportion, dtype: float64
#
# Phrase: i wanted to
# label_0
# 0    0.785714
# 1    0.214286
# Name: proportion, dtype: float64
# label_1
# 1    0.588146
# 0    0.411854
# Name: proportion, dtype: float64
# label_2
# 1    0.62614
# 0    0.37386
# Name: proportion, dtype: float64
# label_3
# 1    0.583587
# 0    0.416413
# Name: proportion, dtype: float64
#
# Phrase: i don't know
# label_0
# 0    0.90566
# 1    0.09434
# Name: proportion, dtype: float64
# label_1
# 1    0.702401
# 0    0.297599
# Name: proportion, dtype: float64
# label_2
# 1    0.710978
# 0    0.289022
# Name: proportion, dtype: float64
# label_3
# 1    0.655232
# 0    0.344768
# Name: proportion, dtype: float64
#
# Phrase: a lot of
# label_0
# 0    0.777013
# 1    0.222987
# Name: proportion, dtype: float64
# label_1
# 1    0.55265
# 0    0.44735
# Name: proportion, dtype: float64
# label_2
# 1    0.637302
# 0    0.362698
# Name: proportion, dtype: float64
# label_3
# 1    0.565038
# 0    0.434962
# Name: proportion, dtype: float64
#
# Phrase: i have a
# label_0
# 0    0.855025
# 1    0.144975
# Name: proportion, dtype: float64
# label_1
# 1    0.603515
# 0    0.396485
# Name: proportion, dtype: float64
# label_2
# 1    0.684789
# 0    0.315211
# Name: proportion, dtype: float64
# label_3
# 1    0.638111
# 0    0.361889
# Name: proportion, dtype: float64
#
# Phrase: i have been
# label_0
# 0    0.844141
# 1    0.155859
# Name: proportion, dtype: float64
# label_1
# 1    0.623436
# 0    0.376564
# Name: proportion, dtype: float64
# label_2
# 1    0.671217
# 0    0.328783
# Name: proportion, dtype: float64
# label_3
# 1    0.604096
# 0    0.395904
# Name: proportion, dtype: float64
#
# Phrase: i want to
# label_0
# 0    0.863048
# 1    0.136952
# Name: proportion, dtype: float64
# label_1
# 1    0.672311
# 0    0.327689
# Name: proportion, dtype: float64
# label_2
# 1    0.64243
# 0    0.35757
# Name: proportion, dtype: float64
# label_3
# 1    0.618028
# 0    0.381972
# Name: proportion, dtype: float64
#
# Phrase: i am not
# label_0
# 0    0.843177
# 1    0.156823
# Name: proportion, dtype: float64
# label_1
# 1    0.623218
# 0    0.376782
# Name: proportion, dtype: float64
# label_2
# 1    0.604888
# 0    0.395112
# Name: proportion, dtype: float64
# label_3
# 1    0.580448
# 0    0.419552
# Name: proportion, dtype: float64
#
# Phrase: be able to
# label_0
# 0    0.869497
# 1    0.130503
# Name: proportion, dtype: float64
# label_1
# 1    0.654088
# 0    0.345912
# Name: proportion, dtype: float64
# label_2
# 1    0.677673
# 0    0.322327
# Name: proportion, dtype: float64
# label_3
# 1    0.669811
# 0    0.330189
# Name: proportion, dtype: float64
#
# Phrase: when i was
# label_0
# 0    0.848574
# 1    0.151426
# Name: proportion, dtype: float64
# label_1
# 1    0.686332
# 0    0.313668
# Name: proportion, dtype: float64
# label_2
# 1    0.669617
# 0    0.330383
# Name: proportion, dtype: float64
# label_3
# 1    0.606686
# 0    0.393314
# Name: proportion, dtype: float64
#
# Phrase: i don't think
# label_0
# 0    0.869822
# 1    0.130178
# Name: proportion, dtype: float64
# label_1
# 1    0.674556
# 0    0.325444
# Name: proportion, dtype: float64
# label_2
# 1    0.680473
# 0    0.319527
# Name: proportion, dtype: float64
# label_3
# 1    0.62426
# 0    0.37574
# Name: proportion, dtype: float64

# %%
# df has columns: 'text' (str), 'label' (int or str)
import pandas as pd

df = pd.read_csv('Datasets/journal_reddit_posts_multilabel.csv')

def phrase_lift(df, phrase, positive_label):
    has = df['text'].str.contains(phrase, case=False, na=False)
    p_label = (df['label'] == positive_label).mean()
    p_label_given = df.loc[has, 'label'].eq(positive_label).mean()
    return p_label, p_label_given, (p_label_given / (p_label + 1e-12))
    
for ph in common_phrases:
    overall, given, lift = phrase_lift(df, ph, positive_label=1)  # adapt positive label
    print(ph, "P(label)=%.3f P(label|phrase)=%.3f lift=%.2f" % (overall, given, lift))

# %%
import pandas as pd

# Read your CSV
df = pd.read_csv("neutral_journals_700.csv")

# Add the label columns
df["label_0"] = 1
df["label_1"] = 0
df["label_2"] = 0
df["label_3"] = 0

# Save back to CSV
df.to_csv("neutral_journals_700_final.csv", index=False)

print("✅ Added label columns successfully!")
# Out:
# ✅ Added label columns successfully!

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("resolved_psychforums_dataset.csv")

# Filter rows where label_0 == 1
label0_rows = df[df["label_0"] == 1]

# Randomly sample 300 rows from these
sampled = label0_rows.sample(n=300, random_state=42)  # random_state for reproducibility

# Remove the sampled rows from the original dataframe
filtered_df = df.drop(sampled.index)

# Save to a new CSV if needed
filtered_df.to_csv("filtered_psychforums_dataset.csv", index=False)

print(f"Original dataset size: {len(df)}")
print(f"Filtered dataset size: {len(filtered_df)}")
# Out:
# Original dataset size: 2599
# Filtered dataset size: 2299

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("neutral_journals_700_final.csv")

# Randomly drop 222 rows
df_filtered = df.sample(frac=1, random_state=42).iloc[222:].reset_index(drop=True)

# Save the filtered dataset
df_filtered.to_csv("neutral_journals_700_filtered.csv", index=False)

print(f"Original dataset size: {len(df)}")
print(f"Filtered dataset size: {len(df_filtered)}")
# Out:
# Original dataset size: 700
# Filtered dataset size: 478

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("Datasets/psychforums_multilabel.csv")

# Convert label columns from float to int
label_cols = ["label_0", "label_1", "label_2", "label_3"]
df[label_cols] = df[label_cols].astype(int)

# Save the updated dataset
df.to_csv("Datasets/psychforums_multilabel.csv", index=False)

print(df.head())
print(df.dtypes)
# Out:
#    id                                               text  label_0  label_1  \
# 0   1  how are you feeling today? i had a fight with ...        0        0
# 1   2  how are you feeling today? snaga wrote: a stic...        1        0
# 2   3  how are you feeling today? like there's really...        0        1
# 3   4  how are you feeling today? not good, but not b...        0        0
# 4   5  how are you feeling today? i've been strugglin...        0        1
#
#    label_2  label_3
# 0        1        0
# 1        0        0
# 2        1        0
# 3        1        1
# 4        1        1
# id          int64
# text       object
# label_0     int64
# label_1     int64
# label_2     int64
# label_3     int64
# dtype: object
