# %%
import google.generativeai as genai
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd
from time import sleep

# Step 2: Set Gemini API key
genai.configure(api_key="YOUR_API_KEY")

# Step 3: Load Gemini model
model = genai.GenerativeModel("gemini-2.0-flash")

# Step 4: Define batched classification prompt
def classify_batch(text_batch):
    batched_prompt = """
You are a mental health sentiment classifier. Classify each of the following user texts into one of these 4 labels:

0 → neutral  
1 → low mood / depressed  
2 → anxious / worried  
3 → stressed / overwhelmed

For each input, return only a list of integers (one per text) in the same order. No explanation. Example: [1, 0, 2]

Texts:
""" + "\n\n".join([f"{i+1}. {text}" for i, text in enumerate(text_batch)]) + "\n\nAnswer:"

    try:
        response = model.generate_content(batched_prompt)
        preds_text = response.text.strip()
        preds = eval(preds_text.split("\n")[0])
        return preds
    except Exception as e:
        print("Error:", e)
        return [None] * len(text_batch)

# %%
df = pd.read_csv('Datasets/journal_reddit_posts.csv')

texts = df['text'].tolist()
true_labels = df['label'].tolist()
ids = df['id'].tolist()

# %%
import time

# Step 6: Predict in batches with rate limit handling
predicted_labels = []
batch_size = 3

for i in range(0, len(texts), batch_size):
    batch_texts = texts[i:i+batch_size]

    try:
        batch_preds = classify_batch(batch_texts)
        
        # Check output shape (sanity)
        if len(batch_preds) != batch_size:
            print(f"⚠️ Unexpected prediction count at batch {i//batch_size + 1}: {batch_preds}")
        
        predicted_labels.extend(batch_preds)
        print(f"✅ Batch {i//batch_size + 1}: {batch_preds}")
        time.sleep(5)  # Delay between requests to avoid triggering RPD
    except Exception as e:
        print(f"❌ Error on batch {i//batch_size + 1}: {e}")
        if "quota" in str(e).lower() or "rate" in str(e).lower() or "429" in str(e):
            print("🛑 Rate limit or quota exceeded. Stopping.")
            break
# Out:
# ✅ Batch 1: [0, 0, 0]
# ✅ Batch 2: [2, 1, 0]
# ✅ Batch 3: [0, 2, 0]
# ✅ Batch 4: [0, 0, 0]
# ✅ Batch 5: [2, 1, 0]
# ✅ Batch 6: [1, 0, 0]
# ✅ Batch 7: [3, 1, 0]
# ✅ Batch 8: [0, 0, 0]
# ✅ Batch 9: [0, 0, 0]
# ✅ Batch 10: [0, 3, 2]
# ✅ Batch 11: [3, 0, 2]
# ✅ Batch 12: [0, 0, 3]
# ✅ Batch 13: [0, 0, 0]
# ✅ Batch 14: [0, 3, 1]
# ✅ Batch 15: [1, 0, 3]
# ✅ Batch 16: [0, 0, 1]
# ✅ Batch 17: [2, 0, 0]
# ✅ Batch 18: [1, 0, 0]
# ✅ Batch 19: [0, 0, 3]
# ✅ Batch 20: [2, 2, 0]
# ✅ Batch 21: [0, 0, 3]
# ✅ Batch 22: [1, 0, 0]
# ✅ Batch 23: [0, 0, 0]
# ✅ Batch 24: [0, 0, 0]
# ✅ Batch 25: [0, 0, 2]
# ✅ Batch 26: [1, 0, 0]
# ✅ Batch 27: [1, 0, 0]
# ✅ Batch 28: [2, 0, 0]
# ✅ Batch 29: [0, 0, 0]
# ✅ Batch 30: [0, 0, 2]
# ✅ Batch 31: [0, 0, 0]
# ✅ Batch 32: [0, 2, 0]
# ✅ Batch 33: [0, 1, 0]
# ✅ Batch 34: [0, 0, 0]
# ✅ Batch 35: [0, 0, 3]
# ✅ Batch 36: [0, 0, 0]
# ✅ Batch 37: [0, 0, 2]
# ✅ Batch 38: [0, 0, 0]
# ✅ Batch 39: [0, 2, 3]
# ✅ Batch 40: [0, 2, 0]
# ✅ Batch 41: [0, 0, 0]
# ✅ Batch 42: [0, 0, 0]
# ✅ Batch 43: [0, 0, 0]
# ✅ Batch 44: [2, 1, 0]
# ✅ Batch 45: [0, 0, 0]
# ✅ Batch 46: [2, 0, 0]
# ✅ Batch 47: [0, 2, 0]
# ✅ Batch 48: [0, 0, 0]
# ✅ Batch 49: [0, 0, 0]
# ✅ Batch 50: [0, 0, 0]
# ✅ Batch 51: [0, 0, 0]
# ✅ Batch 52: [0, 0, 0]
# ✅ Batch 53: [0, 0, 3]
# ✅ Batch 54: [0, 0, 0]
# ✅ Batch 55: [0, 0, 3]
# ✅ Batch 56: [0, 0, 1]
# ✅ Batch 57: [0, 0, 0]
# ✅ Batch 58: [2, 0, 1]
# ✅ Batch 59: [2, 2, 0]
# ✅ Batch 60: [0, 0, 1]
# ✅ Batch 61: [0, 0, 0]
# ✅ Batch 62: [1, 0, 0]
# ✅ Batch 63: [3, 0, 0]
# ✅ Batch 64: [0, 0, 0]
# ✅ Batch 65: [2, 0, 0]
# ✅ Batch 66: [1, 2, 2]
# ✅ Batch 67: [0, 0, 0]
# ✅ Batch 68: [0, 1, 0]
# ✅ Batch 69: [0, 3, 0]
# ✅ Batch 70: [0, 0, 0]
# ✅ Batch 71: [0, 0, 0]
# ✅ Batch 72: [0, 3, 0]
# ✅ Batch 73: [0, 0, 0]
# ✅ Batch 74: [0, 0, 0]
# ✅ Batch 75: [2, 0, 0]
# ✅ Batch 76: [0, 0, 3]
# ✅ Batch 77: [0, 0, 0]
# ✅ Batch 78: [0, 1, 3]
# ✅ Batch 79: [2, 0, 0]
# ✅ Batch 80: [0, 0, 0]
# ✅ Batch 81: [3, 0, 0]
# ✅ Batch 82: [3, 2, 0]
# ✅ Batch 83: [0, 2, 0]
# ✅ Batch 84: [0, 2, 0]
# ✅ Batch 85: [0, 0, 0]
# ✅ Batch 86: [2, 0, 0]
# ✅ Batch 87: [3, 0, 0]
# ✅ Batch 88: [3, 0, 0]
# ✅ Batch 89: [1, 2, 3]
# ✅ Batch 90: [0, 0, 0]
# ✅ Batch 91: [0, 1, 0]
# ✅ Batch 92: [0, 0, 0]
# ✅ Batch 93: [0, 2, 0]
# ✅ Batch 94: [0, 0, 0]
# ✅ Batch 95: [0, 1, 0]
# ✅ Batch 96: [1, 0, 0]
# ✅ Batch 97: [2, 2, 0]
# ✅ Batch 98: [0, 0, 0]
# ✅ Batch 99: [1, 0, 0]
# ✅ Batch 100: [0, 0, 0]
# ✅ Batch 101: [1, 2, 0]
# ✅ Batch 102: [3, 0, 0]
# ✅ Batch 103: [0, 0, 3]
# ✅ Batch 104: [0, 0, 3]
# ✅ Batch 105: [0, 0, 0]
# ✅ Batch 106: [2, 1, 0]
# ✅ Batch 107: [0, 2, 0]
# ✅ Batch 108: [3, 0, 0]
# ✅ Batch 109: [0, 0, 0]
# ✅ Batch 110: [0, 2, 0]
# ✅ Batch 111: [1, 1, 0]
# ✅ Batch 112: [0, 2, 0]
# ✅ Batch 113: [0, 0, 0]
# ✅ Batch 114: [0, 0, 0]
# ✅ Batch 115: [0, 0, 3]
# ✅ Batch 116: [0, 0, 0]
# ✅ Batch 117: [2, 0, 0]
# ✅ Batch 118: [0, 0, 0]
# ✅ Batch 119: [0, 0, 0]
# ✅ Batch 120: [2, 0, 0]
# ✅ Batch 121: [0, 0, 0]
# ✅ Batch 122: [1, 0, 3]
# ✅ Batch 123: [3, 1, 2]
# ✅ Batch 124: [0, 0, 0]
# ✅ Batch 125: [0, 0, 3]
# ✅ Batch 126: [0, 0, 2]
# ✅ Batch 127: [3, 2, 0]
# ✅ Batch 128: [0, 0, 0]
# ✅ Batch 129: [0, 0, 0]
# ✅ Batch 130: [0, 0, 2]
# ✅ Batch 131: [0, 0, 0]
# ✅ Batch 132: [0, 0, 0]
# ✅ Batch 133: [0, 0, 0]
# ✅ Batch 134: [0, 0, 0]
# ✅ Batch 135: [0, 0, 3]
# ✅ Batch 136: [0, 1, 1]
# ✅ Batch 137: [1, 0, 3]
# ✅ Batch 138: [0, 0, 3]
# ✅ Batch 139: [0, 0, 3]
# ✅ Batch 140: [0, 0, 0]
# ✅ Batch 141: [0, 2, 0]
# ✅ Batch 142: [1, 0, 0]
# ✅ Batch 143: [0, 0, 0]
# ✅ Batch 144: [0, 0, 0]
# ✅ Batch 145: [0, 0, 0]
# ✅ Batch 146: [0, 2, 1]
# ✅ Batch 147: [0, 0, 3]
# ✅ Batch 148: [0, 0, 0]
# ✅ Batch 149: [0, 0, 0]
# ✅ Batch 150: [0, 3, 0]
# ✅ Batch 151: [0, 0, 0]
# ✅ Batch 152: [0, 0, 0]
# ✅ Batch 153: [0, 2, 0]
# ✅ Batch 154: [0, 2, 3]
# ✅ Batch 155: [0, 0, 0]
# ✅ Batch 156: [0, 0, 0]
# ✅ Batch 157: [0, 0, 0]
# ✅ Batch 158: [3, 0, 0]
# ✅ Batch 159: [0, 0, 0]
# ✅ Batch 160: [0, 0, 1]
# ✅ Batch 161: [0, 2, 0]
# ✅ Batch 162: [0, 0, 0]
# ✅ Batch 163: [0, 0, 0]
# ✅ Batch 164: [0, 0, 0]
# ✅ Batch 165: [0, 0, 0]
# ✅ Batch 166: [0, 2, 2]
# ✅ Batch 167: [0, 3, 0]
# ✅ Batch 168: [0, 0, 3]
# ✅ Batch 169: [0, 0, 0]
# ✅ Batch 170: [0, 0, 0]
# ✅ Batch 171: [0, 1, 0]
# ✅ Batch 172: [0, 0, 0]
# ✅ Batch 173: [0, 2, 0]
# ✅ Batch 174: [0, 0, 0]
# ✅ Batch 175: [3, 0, 0]
# ✅ Batch 176: [0, 3, 0]
# ✅ Batch 177: [0, 3, 0]
# Error: invalid syntax (<string>, line 1)
# ✅ Batch 178: [None, None, None]
# ✅ Batch 179: [1, 0, 0]
# ✅ Batch 180: [0, 0, 0]
# ✅ Batch 181: [0, 0, 0]
# ✅ Batch 182: [0, 3, 0]
# ✅ Batch 183: [0, 1, 0]
# ✅ Batch 184: [2, 0, 0]
# ✅ Batch 185: [0, 0, 0]
# ✅ Batch 186: [0, 0, 0]
# ✅ Batch 187: [0, 0, 0]
# ⚠️ Unexpected prediction count at batch 188: [0, 0, 0, 0, 0, 2, 0]
# ✅ Batch 188: [0, 0, 0, 0, 0, 2, 0]
# ✅ Batch 189: [1, 0, 3]
# ✅ Batch 190: [0, 0, 0]
# ✅ Batch 191: [0, 0, 0]
# ✅ Batch 192: [0, 0, 0]
# ✅ Batch 193: [2, 0, 0]
# ✅ Batch 194: [3, 0, 1]
# ✅ Batch 195: [2, 2, 0]
# ✅ Batch 196: [0, 2, 0]
# ✅ Batch 197: [0, 3, 0]
# ✅ Batch 198: [0, 0, 0]
# ✅ Batch 199: [0, 2, 0]
# ✅ Batch 200: [0, 0, 0]
# ✅ Batch 201: [0, 2, 0]
# ✅ Batch 202: [0, 0, 3]
# ✅ Batch 203: [0, 2, 3]
# ✅ Batch 204: [0, 0, 0]
# ✅ Batch 205: [3, 0, 2]
# ✅ Batch 206: [2, 3, 0]
# ✅ Batch 207: [0, 0, 0]
# ✅ Batch 208: [0, 0, 0]
# ✅ Batch 209: [3, 0, 0]
# ✅ Batch 210: [0, 0, 3]
# ✅ Batch 211: [2, 2, 0]
# ✅ Batch 212: [3, 0, 0]
# ✅ Batch 213: [0, 0, 0]
# ✅ Batch 214: [0, 0, 0]
# ✅ Batch 215: [0, 1, 2]
# ✅ Batch 216: [0, 0, 0]
# ✅ Batch 217: [1, 0, 0]
# ✅ Batch 218: [0, 2, 3]
# ✅ Batch 219: [0, 0, 0]
# ✅ Batch 220: [3, 0, 0]
# ✅ Batch 221: [0, 2, 0]
# ✅ Batch 222: [0, 0, 0]
# ✅ Batch 223: [0, 0, 0]
# ✅ Batch 224: [0, 3, 0]
# ✅ Batch 225: [2, 0, 1]
# ✅ Batch 226: [1, 1, 3]
# ✅ Batch 227: [2, 3, 3]
# ✅ Batch 228: [3, 1, 3]
# ✅ Batch 229: [3, 1, 3]
# ✅ Batch 230: [1, 2, 1]
# ✅ Batch 231: [0, 3, 3]
# ✅ Batch 232: [1, 2, 3]
# ✅ Batch 233: [3, 1, 3]
# ✅ Batch 234: [1, 1, 3]
# ✅ Batch 235: [3, 1, 1]
# ✅ Batch 236: [3, 2, 0]
# ✅ Batch 237: [0, 3, 3]
# ✅ Batch 238: [1, 1, 2]
# ✅ Batch 239: [3, 3, 1]
# ✅ Batch 240: [1, 1, 1]
# ✅ Batch 241: [3, 2, 3]
# ✅ Batch 242: [1, 2, 1]
# ✅ Batch 243: [1, 1, 3]
# ✅ Batch 244: [2, 2, 3]
# ✅ Batch 245: [3, 1, 1]
# ✅ Batch 246: [1, 1, 3]
# ✅ Batch 247: [1, 0, 1]
# ✅ Batch 248: [1, 2, 0]
# ✅ Batch 249: [0, 3, 1]
# ✅ Batch 250: [0, 1, 3]
# ✅ Batch 251: [1, 3, 2]
# ✅ Batch 252: [1, 2, 1]
# ✅ Batch 253: [3, 1, 0]
# ✅ Batch 254: [1, 0, 1]
# ✅ Batch 255: [1, 2, 3]
# ✅ Batch 256: [1, 1, 1]
# ✅ Batch 257: [3, 1, 3]
# ✅ Batch 258: [2, 1, 3]
# ✅ Batch 259: [3, 1, 2]
# ✅ Batch 260: [1, 1, 3]
# ✅ Batch 261: [1, 1, 1]
# ✅ Batch 262: [1, 2, 1]
# ✅ Batch 263: [1, 2, 0]
# ✅ Batch 264: [3, 0, 3]
# ✅ Batch 265: [3, 0, 1]
# ✅ Batch 266: [1, 2, 3]
# ✅ Batch 267: [1, 2, 3]
# ✅ Batch 268: [1, 3, 3]
# ✅ Batch 269: [2, 3, 0]
# ✅ Batch 270: [3, 0, 0]
# ✅ Batch 271: [0, 1, 1]
# ✅ Batch 272: [1, 2, 1]
# ✅ Batch 273: [1, 1, 1]
# ✅ Batch 274: [1, 3, 1]
# ✅ Batch 275: [2, 3, 3]
# ✅ Batch 276: [1, 3, 1]
# ✅ Batch 277: [1, 1, 1]
# ✅ Batch 278: [3, 2, 3]
# ✅ Batch 279: [1, 2, 3]
# ✅ Batch 280: [2, 1, 1]
# ✅ Batch 281: [1, 3, 1]
# ✅ Batch 282: [3, 3, 1]
# ✅ Batch 283: [1, 3, 1]
# ✅ Batch 284: [3, 3, 3]
# ✅ Batch 285: [3, 1, 1]
# ✅ Batch 286: [1, 3, 0]
# ✅ Batch 287: [3, 1, 1]
# ✅ Batch 288: [3, 2, 3]
# ✅ Batch 289: [3, 2, 1]
# ✅ Batch 290: [1, 1, 1]
# ✅ Batch 291: [2, 3, 1]
# ✅ Batch 292: [1, 1, 1]
# ✅ Batch 293: [1, 3, 1]
# Error: invalid syntax (<string>, line 1)
# ✅ Batch 294: [None, None, None]
# ✅ Batch 295: [3, 2, 2]
# ✅ Batch 296: [1, 2, 3]
# ✅ Batch 297: [1, 3, 3]
# ✅ Batch 298: [0, 3, 3]
# ✅ Batch 299: [1, 3, 0]
# ✅ Batch 300: [1, 2, 2]
# ✅ Batch 301: [1, 2, 3]
# ✅ Batch 302: [2, 2, 1]
# ✅ Batch 303: [2, 1, 3]
# ✅ Batch 304: [1, 2, 3]
# ✅ Batch 305: [3, 1, 1]
# ✅ Batch 306: [1, 1, 1]
# ✅ Batch 307: [2, 3, 0]
# ✅ Batch 308: [2, 0, 3]
# ✅ Batch 309: [3, 2, 3]
# ✅ Batch 310: [1, 0, 3]
# ✅ Batch 311: [1, 2, 3]
# ✅ Batch 312: [3, 1, 0]
# ✅ Batch 313: [3, 0, 1]
# ✅ Batch 314: [2, 1, 3]
# ✅ Batch 315: [1, 2, 3]
# ✅ Batch 316: [3, 2, 1]
# ✅ Batch 317: [1, 3, 0]
# ✅ Batch 318: [1, 2, 1]
# ✅ Batch 319: [1, 1, 1]
# ✅ Batch 320: [3, 2, 3]
# ✅ Batch 321: [3, 1, 2]
# ✅ Batch 322: [3, 0, 1]
# Error: invalid syntax (<string>, line 1)
# ✅ Batch 323: [None, None, None]
# Error: invalid syntax (<string>, line 1)
# ✅ Batch 324: [None, None, None]
# ✅ Batch 325: [1, 2, 2]
# ✅ Batch 326: [1, 2, 2]
# ✅ Batch 327: [2, 2, 1]
# ✅ Batch 328: [1, 3, 1]
# ✅ Batch 329: [1, 2, 3]
# ✅ Batch 330: [1, 1, 2]
# ✅ Batch 331: [1, 1, 3]
# ✅ Batch 332: [1, 2, 3]
# ✅ Batch 333: [1, 1, 3]
# ✅ Batch 334: [3, 1, 0]
# ✅ Batch 335: [0, 0, 3]
# ✅ Batch 336: [3, 2, 2]
# ✅ Batch 337: [3, 1, 1]
# ✅ Batch 338: [1, 2, 3]
# ✅ Batch 339: [0, 1, 2]
# ✅ Batch 340: [3, 1, 1]
# ✅ Batch 341: [1, 3, 2]
# ✅ Batch 342: [3, 3, 1]
# ✅ Batch 343: [1, 0, 3]
# ✅ Batch 344: [3, 1, 2]
# ✅ Batch 345: [1, 3, 1]
# ✅ Batch 346: [1, 1, 2]
# ✅ Batch 347: [2, 3, 0]
# ✅ Batch 348: [1, 1, 3]
# ✅ Batch 349: [3, 0, 3]
# ✅ Batch 350: [0, 3, 1]
# ✅ Batch 351: [3, 0, 1]
# ✅ Batch 352: [3, 3, 3]
# ✅ Batch 353: [3, 1, 0]
# ✅ Batch 354: [3, 3, 3]
# ✅ Batch 355: [1, 3, 1]
# ✅ Batch 356: [1, 3, 1]
# ✅ Batch 357: [3, 1, 3]
# ✅ Batch 358: [1, 1, 1]
# ✅ Batch 359: [1, 3, 1]
# ✅ Batch 360: [3, 0, 1]
# ✅ Batch 361: [1, 3, 3]
# ✅ Batch 362: [3, 2, 0]
# ✅ Batch 363: [1, 2, 1]
# ✅ Batch 364: [1, 3, 3]
# ✅ Batch 365: [2, 1, 3]
# ✅ Batch 366: [3, 3, 3]
# ✅ Batch 367: [1, 3, 1]
# ✅ Batch 368: [1, 1, 1]
# ✅ Batch 369: [1, 2, 2]
# ✅ Batch 370: [2, 0, 1]
# ✅ Batch 371: [3, 0, 1]
# ✅ Batch 372: [0, 1, 2]
# Error: invalid syntax (<string>, line 1)
# ✅ Batch 373: [None, None, None]
# ✅ Batch 374: [1, 3, 3]
# ✅ Batch 375: [1, 3, 3]
# ✅ Batch 376: [1, 2, 3]
# ✅ Batch 377: [3, 1, 1]
# ✅ Batch 378: [3, 2, 2]
# ✅ Batch 379: [1, 3, 3]
# ✅ Batch 380: [3, 3, 1]
# ✅ Batch 381: [3, 3, 3]
# ✅ Batch 382: [1, 2, 1]
# ✅ Batch 383: [1, 2, 1]
# ✅ Batch 384: [1, 1, 1]
# ✅ Batch 385: [1, 3, 3]
# ✅ Batch 386: [1, 1, 1]
# ✅ Batch 387: [3, 0, 1]
# ✅ Batch 388: [1, 1, 2]
# ✅ Batch 389: [2, 3, 1]
# ✅ Batch 390: [3, 2, 3]
# ✅ Batch 391: [1, 2, 1]
# ✅ Batch 392: [1, 1, 1]
# ✅ Batch 393: [1, 1, 2]
# ✅ Batch 394: [1, 3, 1]
# ✅ Batch 395: [1, 0, 1]
# ✅ Batch 396: [1, 0, 3]
# ✅ Batch 397: [1, 2, 3]
# ✅ Batch 398: [3, 1, 3]
# ✅ Batch 399: [3, 3, 1]
# ✅ Batch 400: [3, 0, 1]
# ✅ Batch 401: [3, 0, 1]
# ✅ Batch 402: [1, 1, 3]
# ✅ Batch 403: [1, 1, 3]
# ✅ Batch 404: [3, 3, 3]
# ✅ Batch 405: [2, 1, 1]
# ✅ Batch 406: [1, 1, 3]
# ✅ Batch 407: [1, 3, 1]
# ✅ Batch 408: [3, 3, 3]
# ✅ Batch 409: [1, 1, 3]
# ✅ Batch 410: [3, 1, 3]
# ✅ Batch 411: [1, 2, 2]
# ✅ Batch 412: [3, 3, 1]
# ✅ Batch 413: [2, 2, 1]
# ✅ Batch 414: [3, 3, 3]
# ✅ Batch 415: [3, 1, 3]
# ✅ Batch 416: [3, 3, 3]
# ✅ Batch 417: [1, 1, 3]
# ✅ Batch 418: [3, 2, 1]
# ✅ Batch 419: [3, 2, 2]
# ✅ Batch 420: [3, 0, 0]
# ✅ Batch 421: [2, 2, 1]
# ✅ Batch 422: [1, 2, 3]
# ✅ Batch 423: [1, 3, 3]
# ✅ Batch 424: [2, 3, 3]
# ✅ Batch 425: [1, 1, 3]
# ✅ Batch 426: [1, 1, 2]
# ✅ Batch 427: [3, 3, 1]
# ✅ Batch 428: [3, 1, 2]
# ✅ Batch 429: [3, 2, 3]
# ✅ Batch 430: [0, 3, 2]
# ✅ Batch 431: [1, 1, 3]
# ✅ Batch 432: [2, 1, 2]
# ✅ Batch 433: [3, 1, 3]
# ✅ Batch 434: [2, 1, 0]
# ✅ Batch 435: [1, 2, 3]
# ✅ Batch 436: [3, 1, 3]
# ✅ Batch 437: [3, 1, 1]
# ✅ Batch 438: [3, 1, 3]
# ✅ Batch 439: [1, 0, 3]
# ✅ Batch 440: [3, 1, 3]
# ✅ Batch 441: [1, 0, 3]
# ✅ Batch 442: [1, 1, 2]
# ✅ Batch 443: [2, 1, 3]
# ✅ Batch 444: [1, 3, 2]
# ✅ Batch 445: [3, 1, 3]
# ✅ Batch 446: [3, 2, 3]
# ✅ Batch 447: [3, 3, 0]
# ✅ Batch 448: [1, 3, 1]
# ✅ Batch 449: [2, 2, 1]
# ✅ Batch 450: [1, 2, 3]
# ✅ Batch 451: [3, 1, 1]
# ✅ Batch 452: [1, 3, 1]
# ✅ Batch 453: [0, 2, 2]
# ✅ Batch 454: [3, 2, 1]
# ✅ Batch 455: [2, 0, 1]
# ✅ Batch 456: [2, 1, 0]
# ✅ Batch 457: [0, 1, 1]
# ✅ Batch 458: [3, 0, 1]
# ✅ Batch 459: [3, 1, 0]
# ✅ Batch 460: [2, 3, 1]
# ✅ Batch 461: [2, 2, 3]
# ✅ Batch 462: [2, 2, 0]
# ✅ Batch 463: [3, 2, 1]
# ✅ Batch 464: [1, 2, 1]
# ✅ Batch 465: [3, 2, 1]
# ✅ Batch 466: [1, 2, 2]
# ✅ Batch 467: [1, 0, 3]
# ✅ Batch 468: [3, 0, 1]
# ✅ Batch 469: [1, 3, 2]
# ✅ Batch 470: [1, 1, 3]
# ✅ Batch 471: [2, 1, 2]
# ✅ Batch 472: [2, 2, 2]
# ✅ Batch 473: [2, 2, 2]
# ✅ Batch 474: [1, 2, 2]
# ✅ Batch 475: [2, 2, 2]
# ✅ Batch 476: [2, 1, 2]
# ✅ Batch 477: [2, 2, 2]
# ✅ Batch 478: [1, 2, 2]
# ✅ Batch 479: [2, 2, 2]
# ✅ Batch 480: [1, 2, 2]
# ✅ Batch 481: [2, 2, 2]
# ✅ Batch 482: [2, 1, 2]
# ✅ Batch 483: [1, 2, 2]
# ✅ Batch 484: [2, 2, 2]
# ✅ Batch 485: [2, 2, 2]
# ✅ Batch 486: [1, 2, 2]
# ✅ Batch 487: [2, 0, 2]
# ✅ Batch 488: [2, 2, 2]
# ✅ Batch 489: [2, 2, 2]
# ✅ Batch 490: [2, 2, 2]
# ✅ Batch 491: [2, 2, 2]
# ✅ Batch 492: [2, 2, 2]
# ✅ Batch 493: [2, 2, 2]
# ✅ Batch 494: [2, 2, 2]
# ✅ Batch 495: [2, 2, 2]
# ✅ Batch 496: [1, 1, 2]
# ✅ Batch 497: [2, 2, 2]
# ✅ Batch 498: [2, 2, 3]
# ✅ Batch 499: [2, 2, 2]
# ✅ Batch 500: [2, 3, 2]
# ✅ Batch 501: [2, 3, 2]
# ✅ Batch 502: [2, 2, 2]
# ✅ Batch 503: [2, 2, 2]
# ✅ Batch 504: [3, 2, 2]
# ✅ Batch 505: [2, 2, 2]
# ✅ Batch 506: [2, 2, 2]
# ✅ Batch 507: [2, 2, 1]
# ✅ Batch 508: [2, 2, 2]
# ✅ Batch 509: [2, 2, 2]
# ✅ Batch 510: [2, 2, 2]
# ✅ Batch 511: [2, 2, 2]
# ✅ Batch 512: [2, 2, 2]
# ✅ Batch 513: [2, 3, 2]
# ✅ Batch 514: [2, 2, 2]
# ✅ Batch 515: [2, 2, 2]
# ✅ Batch 516: [1, 3, 2]
# ✅ Batch 517: [2, 2, 1]
# ✅ Batch 518: [2, 2, 2]
# ✅ Batch 519: [2, 2, 2]
# ✅ Batch 520: [2, 1, 2]
# ✅ Batch 521: [0, 3, 2]
# ✅ Batch 522: [2, 1, 2]
# ✅ Batch 523: [2, 2, 2]
# ✅ Batch 524: [2, 0, 2]
# ✅ Batch 525: [2, 2, 2]
# ✅ Batch 526: [2, 2, 1]
# ✅ Batch 527: [2, 0, 2]
# ✅ Batch 528: [2, 3, 0]
# ✅ Batch 529: [1, 2, 3]
# ✅ Batch 530: [2, 1, 2]
# ✅ Batch 531: [2, 2, 2]
# ✅ Batch 532: [2, 2, 2]
# ✅ Batch 533: [2, 2, 2]
# ✅ Batch 534: [2, 3, 2]
# ✅ Batch 535: [2, 2, 2]
# ✅ Batch 536: [2, 2, 0]
# ✅ Batch 537: [1, 2, 3]
# ✅ Batch 538: [2, 2, 3]
# ✅ Batch 539: [2, 2, 2]
# ✅ Batch 540: [2, 1, 2]
# ✅ Batch 541: [0, 2, 3]
# ✅ Batch 542: [2, 2, 2]
# ✅ Batch 543: [1, 2, 2]
# ✅ Batch 544: [2, 2, 1]
# ✅ Batch 545: [2, 2, 2]
# ✅ Batch 546: [2, 2, 2]
# ✅ Batch 547: [2, 2, 0]
# ✅ Batch 548: [2, 2, 2]
# ✅ Batch 549: [2, 2, 2]
# ✅ Batch 550: [3, 2, 2]
# ✅ Batch 551: [1, 3, 3]
# ✅ Batch 552: [2, 2, 2]
# ✅ Batch 553: [2, 2, 2]
# ✅ Batch 554: [2, 2, 2]
# ✅ Batch 555: [2, 2, 1]
# ✅ Batch 556: [2, 2, 2]
# ✅ Batch 557: [2, 1, 2]
# ✅ Batch 558: [2, 2, 2]
# ✅ Batch 559: [3, 2, 2]
# ✅ Batch 560: [2, 2, 2]
# ✅ Batch 561: [2, 2, 2]
# ✅ Batch 562: [2, 3, 2]
# ✅ Batch 563: [2, 2, 1]
# ✅ Batch 564: [3, 2, 2]
# ✅ Batch 565: [3, 2, 1]
# ✅ Batch 566: [2, 2, 0]
# ✅ Batch 567: [2, 2, 2]
# ✅ Batch 568: [2, 2, 2]
# ✅ Batch 569: [2, 2, 2]
# ✅ Batch 570: [2, 2, 2]
# ✅ Batch 571: [2, 2, 2]
# ✅ Batch 572: [2, 1, 2]
# ✅ Batch 573: [2, 0, 2]
# ✅ Batch 574: [2, 2, 2]
# ✅ Batch 575: [2, 2, 0]
# ✅ Batch 576: [2, 2, 2]
# ✅ Batch 577: [2, 2, 2]
# ✅ Batch 578: [2, 2, 0]
# ✅ Batch 579: [2, 2, 0]
# ✅ Batch 580: [2, 2, 2]
# ✅ Batch 581: [2, 2, 3]
# ✅ Batch 582: [2, 0, 2]
# ✅ Batch 583: [0, 2, 2]
# ✅ Batch 584: [2, 0, 2]
# ✅ Batch 585: [2, 2, 2]
# ✅ Batch 586: [2, 2, 3]
# ✅ Batch 587: [3, 2, 2]
# ✅ Batch 588: [3, 2, 2]
# ✅ Batch 589: [2, 2, 0]
# ✅ Batch 590: [2, 1, 1]
# ✅ Batch 591: [2, 2, 1]
# ✅ Batch 592: [3, 2, 2]
# ✅ Batch 593: [2, 1, 2]
# ✅ Batch 594: [2, 1, 1]
# ✅ Batch 595: [2, 0, 2]
# ✅ Batch 596: [2, 2, 2]
# ✅ Batch 597: [2, 1, 2]
# ✅ Batch 598: [2, 2, 3]
# ✅ Batch 599: [2, 2, 2]
# ✅ Batch 600: [3, 2, 2]
# ✅ Batch 601: [2, 1, 2]
# ✅ Batch 602: [2, 2, 0]
# ✅ Batch 603: [2, 2, 3]
# ✅ Batch 604: [3, 2, 2]
# ✅ Batch 605: [2, 2, 2]
# ✅ Batch 606: [2, 2, 3]
# ✅ Batch 607: [2, 2, 2]
# ✅ Batch 608: [2, 2, 2]
# ✅ Batch 609: [2, 2, 2]
# ✅ Batch 610: [2, 2, 2]
# ✅ Batch 611: [3, 2, 2]
# ✅ Batch 612: [2, 2, 2]
# ✅ Batch 613: [2, 2, 2]
# ✅ Batch 614: [2, 2, 2]
# ✅ Batch 615: [2, 2, 2]
# ✅ Batch 616: [2, 2, 2]
# ✅ Batch 617: [2, 2, 2]
# ✅ Batch 618: [2, 2, 2]
# ✅ Batch 619: [2, 2, 1]
# ✅ Batch 620: [1, 2, 3]
# ✅ Batch 621: [2, 2, 2]
# ✅ Batch 622: [0, 2, 2]
# ✅ Batch 623: [2, 2, 2]
# ✅ Batch 624: [2, 2, 2]
# ✅ Batch 625: [2, 2, 2]
# ✅ Batch 626: [3, 2, 2]
# ✅ Batch 627: [3, 2, 2]
# ✅ Batch 628: [2, 2, 2]
# ✅ Batch 629: [2, 2, 2]
# ✅ Batch 630: [3, 2, 3]
# ✅ Batch 631: [0, 2, 2]
# ✅ Batch 632: [1, 2, 2]
# ✅ Batch 633: [2, 2, 2]
# ✅ Batch 634: [2, 2, 3]
# ✅ Batch 635: [2, 2, 2]
# ✅ Batch 636: [2, 3, 1]
# ✅ Batch 637: [2, 2, 3]
# ✅ Batch 638: [3, 2, 2]
# ✅ Batch 639: [2, 2, 2]
# ✅ Batch 640: [3, 2, 2]
# ✅ Batch 641: [2, 2, 1]
# ✅ Batch 642: [2, 2, 2]
# ✅ Batch 643: [2, 2, 0]
# ✅ Batch 644: [1, 2, 2]
# ✅ Batch 645: [2, 2, 2]
# ✅ Batch 646: [2, 2, 3]
# ✅ Batch 647: [1, 2, 2]
# ✅ Batch 648: [2, 2, 3]
# ✅ Batch 649: [1, 2, 2]
# ✅ Batch 650: [1, 2, 1]
# ✅ Batch 651: [2, 2, 2]
# ✅ Batch 652: [2, 2, 2]
# ✅ Batch 653: [2, 2, 2]
# ✅ Batch 654: [2, 2, 2]
# ✅ Batch 655: [2, 2, 2]
# ✅ Batch 656: [1, 2, 0]
# ✅ Batch 657: [0, 2, 2]
# ✅ Batch 658: [2, 2, 2]
# ✅ Batch 659: [2, 2, 3]
# ✅ Batch 660: [2, 2, 3]
# ✅ Batch 661: [2, 2, 0]
# ✅ Batch 662: [2, 1, 2]
# ✅ Batch 663: [2, 0, 2]
# ✅ Batch 664: [2, 2, 2]
# ✅ Batch 665: [2, 2, 2]
# ✅ Batch 666: [2, 2, 0]
# ✅ Batch 667: [2, 2, 2]
# ✅ Batch 668: [2, 2, 2]
# ✅ Batch 669: [2, 2, 2]
# ✅ Batch 670: [2, 3, 2]
# ✅ Batch 671: [2, 2, 2]
# ✅ Batch 672: [2, 2, 2]
# ✅ Batch 673: [1, 2, 2]
# ✅ Batch 674: [2, 2, 2]
# ✅ Batch 675: [2, 2, 2]
# ✅ Batch 676: [2, 2, 2]
# ✅ Batch 677: [2, 2, 2]
# ✅ Batch 678: [3, 2, 2]
# ✅ Batch 679: [2, 2, 2]
# ✅ Batch 680: [0, 2, 2]
# ✅ Batch 681: [2, 2, 1]
# ✅ Batch 682: [2, 1, 2]
# ✅ Batch 683: [2, 2, 2]
# ✅ Batch 684: [2, 2, 2]
# ✅ Batch 685: [1, 2, 2]
# ✅ Batch 686: [2, 3, 2]
# ✅ Batch 687: [2, 2, 2]
# ✅ Batch 688: [2, 2, 0]
# ✅ Batch 689: [0, 2, 2]
# ✅ Batch 690: [2, 2, 2]
# ✅ Batch 691: [1, 2, 2]
# ✅ Batch 692: [1, 0, 1]
# ✅ Batch 693: [0, 2, 2]
# ✅ Batch 694: [2, 2, 2]
# ✅ Batch 695: [2, 2, 2]
# ✅ Batch 696: [1, 2, 2]
# ✅ Batch 697: [0, 2, 3]
# ✅ Batch 698: [2, 1, 3]
# ✅ Batch 699: [2, 2, 2]
# ✅ Batch 700: [2, 2, 3]
# ✅ Batch 701: [2, 2, 2]
# ✅ Batch 702: [2, 2, 2]
# ✅ Batch 703: [2, 2, 0]
# ✅ Batch 704: [2, 2, 2]
# ✅ Batch 705: [2, 2, 2]
# ✅ Batch 706: [2, 1, 2]
# ✅ Batch 707: [3, 2, 3]
# ✅ Batch 708: [2, 2, 2]
# ✅ Batch 709: [2, 2, 2]
# ✅ Batch 710: [2, 2, 2]
# ✅ Batch 711: [2, 3, 2]
# ✅ Batch 712: [3, 2, 1]
# ✅ Batch 713: [2, 2, 2]
# ✅ Batch 714: [2, 2, 2]
# ✅ Batch 715: [3, 2, 2]
# ✅ Batch 716: [2, 2, 2]
# ✅ Batch 717: [3, 2, 2]
# ✅ Batch 718: [2, 2, 2]
# ✅ Batch 719: [2, 0, 2]
# ✅ Batch 720: [2, 2, 2]
# ✅ Batch 721: [3, 2, 2]
# ✅ Batch 722: [0, 0, 2]
# ✅ Batch 723: [2, 2, 2]
# ✅ Batch 724: [2, 2, 3]
# ✅ Batch 725: [2, 2, 2]
# ✅ Batch 726: [3, 2, 2]
# ✅ Batch 727: [2, 2, 2]
# ✅ Batch 728: [2, 1, 2]
# ✅ Batch 729: [2, 2, 2]
# ✅ Batch 730: [2, 2, 2]
# ✅ Batch 731: [3, 2, 2]
# ✅ Batch 732: [2, 1, 2]
# ✅ Batch 733: [3, 2, 1]
# ✅ Batch 734: [2, 2, 2]
# ✅ Batch 735: [2, 2, 3]
# ✅ Batch 736: [2, 2, 2]
# ✅ Batch 737: [2, 0, 2]
# ✅ Batch 738: [1, 1, 2]
# ✅ Batch 739: [2, 2, 0]
# ✅ Batch 740: [2, 2, 2]
# ✅ Batch 741: [2, 2, 2]
# ✅ Batch 742: [2, 2, 2]
# ✅ Batch 743: [2, 2, 2]
# ✅ Batch 744: [2, 2, 2]
# ✅ Batch 745: [2, 0, 2]
# ✅ Batch 746: [0, 2, 1]
# ✅ Batch 747: [1, 2, 2]
# ✅ Batch 748: [2, 2, 3]
# ✅ Batch 749: [2, 2, 2]
# ✅ Batch 750: [2, 2, 3]
# ✅ Batch 751: [2, 2, 2]
# ✅ Batch 752: [2, 2, 3]
# ✅ Batch 753: [2, 1, 2]
# ✅ Batch 754: [2, 2, 3]
# ✅ Batch 755: [2, 3, 0]
# ✅ Batch 756: [2, 2, 3]
# ✅ Batch 757: [2, 1, 2]
# ✅ Batch 758: [1, 2, 3]
# ✅ Batch 759: [2, 2, 2]
# ✅ Batch 760: [2, 2, 2]
# ✅ Batch 761: [2, 2, 1]
# ✅ Batch 762: [2, 3, 2]
# ✅ Batch 763: [2, 2, 2]
# ✅ Batch 764: [3, 2, 2]
# ✅ Batch 765: [2, 2, 2]
# ✅ Batch 766: [2, 2, 1]
# ✅ Batch 767: [2, 2, 2]
# ✅ Batch 768: [2, 3, 0]
# ✅ Batch 769: [2, 2, 2]
# ✅ Batch 770: [2, 2, 2]
# ✅ Batch 771: [2, 2, 0]
# ✅ Batch 772: [1, 2, 2]
# ✅ Batch 773: [2, 0, 2]
# ✅ Batch 774: [2, 0, 2]
# ✅ Batch 775: [2, 0, 2]
# ✅ Batch 776: [0, 2, 2]
# ✅ Batch 777: [2, 2, 2]
# ✅ Batch 778: [2, 2, 2]
# ✅ Batch 779: [2, 2, 2]
# ✅ Batch 780: [2, 2, 2]
# ✅ Batch 781: [2, 2, 3]
# ✅ Batch 782: [2, 2, 2]
# ✅ Batch 783: [2, 2, 0]
# ✅ Batch 784: [2, 2, 2]
# ✅ Batch 785: [3, 2, 2]
# ✅ Batch 786: [2, 2, 1]
# ✅ Batch 787: [0, 0, 0]
# ✅ Batch 788: [0, 0, 0]
# ✅ Batch 789: [0, 0, 0]
# ✅ Batch 790: [0, 0, 1]
# ✅ Batch 791: [0, 0, 0]
# ✅ Batch 792: [0, 1, 0]
# ✅ Batch 793: [0, 0, 0]
# ✅ Batch 794: [0, 0, 0]
# ✅ Batch 795: [0, 0, 0]
# ✅ Batch 796: [0, 0, 0]
# ✅ Batch 797: [0, 0, 0]
# ✅ Batch 798: [0, 0, 0]
# ✅ Batch 799: [0, 2, 0]
# ✅ Batch 800: [0, 0, 0]
# ✅ Batch 801: [1, 0, 0]
# ✅ Batch 802: [0, 0, 0]
# ✅ Batch 803: [0, 0, 0]
# ✅ Batch 804: [0, 0, 0]
# ✅ Batch 805: [3, 0, 0]
# ✅ Batch 806: [0, 0, 0]
# ✅ Batch 807: [0, 2, 0]
# ✅ Batch 808: [1, 0, 0]
# ✅ Batch 809: [0, 1, 0]
# ✅ Batch 810: [0, 1, 0]
# ✅ Batch 811: [0, 0, 0]
# ✅ Batch 812: [0, 0, 0]
# ✅ Batch 813: [1, 0, 0]
# ✅ Batch 814: [0, 0, 1]
# ✅ Batch 815: [0, 0, 0]
# ✅ Batch 816: [0, 1, 0]
# ✅ Batch 817: [0, 0, 0]
# ✅ Batch 818: [0, 1, 0]
# ✅ Batch 819: [0, 0, 0]
# ✅ Batch 820: [1, 0, 0]
# ✅ Batch 821: [0, 0, 0]
# ✅ Batch 822: [0, 0, 0]
# ✅ Batch 823: [0, 0, 0]
# ✅ Batch 824: [0, 0, 0]
# ✅ Batch 825: [0, 0, 0]
# ✅ Batch 826: [0, 0, 0]
# ✅ Batch 827: [0, 0, 0]
# ✅ Batch 828: [0, 0, 0]
# ✅ Batch 829: [0, 0, 0]
# ✅ Batch 830: [0, 0, 0]
# ✅ Batch 831: [0, 0, 0]
# ✅ Batch 832: [3, 3, 3]
# Error: invalid syntax (<string>, line 1)
# ✅ Batch 833: [None, None, None]
# ✅ Batch 834: [3, 0, 2]
# ✅ Batch 835: [2, 3, 3]
# ✅ Batch 836: [3, 3, 3]
# ✅ Batch 837: [2, 0, 2]
# ✅ Batch 838: [3, 3, 0]
# ✅ Batch 839: [1, 2, 2]
# ✅ Batch 840: [3, 1, 1]
# ✅ Batch 841: [0, 3, 0]
# ✅ Batch 842: [0, 3, 2]
# ✅ Batch 843: [3, 0, 3]
# ✅ Batch 844: [3, 2, 3]
# ✅ Batch 845: [1, 0, 3]
# ✅ Batch 846: [3, 3, 3]
# ✅ Batch 847: [3, 2, 3]
# ✅ Batch 848: [3, 3, 3]
# ✅ Batch 849: [3, 2, 3]
# ✅ Batch 850: [3, 1, 3]
# ✅ Batch 851: [3, 1, 0]
# ✅ Batch 852: [3, 3, 3]
# ✅ Batch 853: [2, 0, 1]
# ✅ Batch 854: [3, 2, 3]
# ✅ Batch 855: [1, 0, 0]
# ✅ Batch 856: [0, 2, 2]
# ✅ Batch 857: [1, 2, 3]
# ✅ Batch 858: [1, 2, 2]
# ✅ Batch 859: [0, 2, 2]
# ✅ Batch 860: [3, 2, 2]
# ✅ Batch 861: [2, 3, 2]
# ✅ Batch 862: [1, 3, 3]
# ✅ Batch 863: [3, 1, 3]
# ✅ Batch 864: [1, 2, 1]
# ✅ Batch 865: [1, 2, 1]
# ✅ Batch 866: [2, 1, 1]
# ✅ Batch 867: [3, 2, 3]
# ✅ Batch 868: [0, 2, 0]
# ✅ Batch 869: [3, 2, 2]
# ✅ Batch 870: [1, 2, 3]
# ✅ Batch 871: [1, 3, 2]
# ✅ Batch 872: [1, 2, 2]
# ✅ Batch 873: [1, 3, 2]
# ✅ Batch 874: [2, 2, 0]
# ✅ Batch 875: [2, 2, 2]
# ✅ Batch 876: [1, 2, 1]
# ✅ Batch 877: [1, 1, 1]
# ✅ Batch 878: [1, 2, 2]
# ✅ Batch 879: [3, 2, 2]
# ✅ Batch 880: [3, 2, 1]
# ✅ Batch 881: [1, 2, 2]
# ✅ Batch 882: [1, 2, 3]
# ✅ Batch 883: [2, 2, 2]
# ✅ Batch 884: [1, 3, 1]
# ✅ Batch 885: [1, 2, 2]
# ✅ Batch 886: [2, 1, 2]
# ✅ Batch 887: [2, 2, 2]
# ✅ Batch 888: [2, 2, 0]
# ✅ Batch 889: [1, 2, 1]
# ✅ Batch 890: [2, 1, 1]
# ✅ Batch 891: [1, 2, 0]
# ✅ Batch 892: [1, 2, 3]
# ✅ Batch 893: [1, 2, 2]
# ✅ Batch 894: [1, 2, 3]
# ✅ Batch 895: [2, 0, 1]
# ✅ Batch 896: [1, 3, 0]
# ✅ Batch 897: [3, 2, 2]
# ✅ Batch 898: [1, 2, 0]
# ✅ Batch 899: [1, 2, 1]
# ✅ Batch 900: [1, 1, 2]
# ✅ Batch 901: [1, 3, 0]
# ✅ Batch 902: [1, 2, 2]
# ✅ Batch 903: [2, 2, 2]
# ✅ Batch 904: [2, 3, 3]
# ✅ Batch 905: [3, 2, 1]
# ✅ Batch 906: [2, 2, 1]
# ✅ Batch 907: [2, 2, 2]
# ✅ Batch 908: [1, 1, 0]
# ✅ Batch 909: [2, 2, 3]
# ✅ Batch 910: [2, 2, 2]
# ✅ Batch 911: [1, 2, 0]
# ✅ Batch 912: [2, 2, 2]
# ✅ Batch 913: [1, 2, 2]
# ✅ Batch 914: [1, 1, 0]
# ✅ Batch 915: [1, 3, 3]
# ✅ Batch 916: [1, 1, 2]
# ✅ Batch 917: [2, 1, 3]
# ✅ Batch 918: [1, 2, 2]
# ✅ Batch 919: [2, 2, 1]
# ✅ Batch 920: [2, 2, 2]
# ✅ Batch 921: [1, 2, 1]
# ✅ Batch 922: [2, 1, 2]
# ✅ Batch 923: [3, 2, 1]
# ✅ Batch 924: [3, 2, 1]
# ✅ Batch 925: [2, 1, 2]
# ✅ Batch 926: [1, 1, 2]
# ✅ Batch 927: [2, 2, 2]
# ✅ Batch 928: [0, 2, 0]
# ✅ Batch 929: [2, 2, 2]
# ✅ Batch 930: [1, 2, 2]
# ✅ Batch 931: [1, 2, 2]
# ✅ Batch 932: [1, 2, 2]
# ✅ Batch 933: [1, 2, 1]
# ✅ Batch 934: [3, 2, 1]
# ✅ Batch 935: [0, 2, 3]
# ✅ Batch 936: [1, 2, 2]
# ✅ Batch 937: [2, 2, 2]
# ✅ Batch 938: [2, 3, 1]
# ✅ Batch 939: [3, 2, 3]
# ✅ Batch 940: [0, 2, 0]
# ✅ Batch 941: [1, 2, 1]
# ✅ Batch 942: [1, 0, 2]
# ✅ Batch 943: [2, 1, 2]
# ✅ Batch 944: [2, 1, 3]
# ✅ Batch 945: [1, 2, 1]
# ✅ Batch 946: [1, 1, 2]
# ✅ Batch 947: [2, 0, 3]
# Error: Invalid operation: The `response.parts` quick accessor requires a single candidate, but but `response.candidates` is empty.
# This appears to be caused by a blocked prompt, see `response.prompt_feedback`: block_reason: PROHIBITED_CONTENT
#
# ✅ Batch 948: [None, None, None]
# ✅ Batch 949: [2, 0, 1]
# ✅ Batch 950: [3, 2, 1]
# ✅ Batch 951: [2, 0, 2]
# ✅ Batch 952: [2, 2, 1]
# ✅ Batch 953: [3, 1, 1]
# ✅ Batch 954: [3, 2, 1]
# ✅ Batch 955: [1, 0, 1]
# ✅ Batch 956: [2, 0, 3]
# ✅ Batch 957: [0, 1, 3]
# ✅ Batch 958: [1, 2, 1]
# ✅ Batch 959: [3, 0, 2]
# ✅ Batch 960: [2, 1, 2]
# ✅ Batch 961: [3, 1, 2]
# ✅ Batch 962: [3, 2, 2]
# ✅ Batch 963: [3, 2, 0]
# ✅ Batch 964: [3, 0, 2]
# ✅ Batch 965: [1, 2, 2]
# ✅ Batch 966: [2, 2, 3]
# ✅ Batch 967: [3, 2, 2]
# ✅ Batch 968: [1, 0, 3]
# ✅ Batch 969: [1, 2, 1]
# ✅ Batch 970: [1, 2, 0]
# ✅ Batch 971: [3, 1, 2]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# ✅ Batch 972: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# ✅ Batch 973: [None, None, None]
# ✅ Batch 974: [3, 0, 2]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 30
# }
# ]
# ✅ Batch 975: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# ✅ Batch 976: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# ✅ Batch 977: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
# ✅ Batch 978: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# ✅ Batch 979: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# ✅ Batch 980: [None, None, None]
# ✅ Batch 981: [2, 2, 2]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# ✅ Batch 982: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# ✅ Batch 983: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# ✅ Batch 984: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# ✅ Batch 985: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# ✅ Batch 986: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# ✅ Batch 987: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# ✅ Batch 988: [None, None, None]
# ✅ Batch 989: [3, 1, 0]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
# ✅ Batch 990: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# ✅ Batch 991: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# ✅ Batch 992: [None, None, None]
# ✅ Batch 993: [2, 2, 3]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# ✅ Batch 994: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# ✅ Batch 995: [None, None, None]
# ✅ Batch 996: [2, 1, 2]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# ✅ Batch 997: [None, None, None]
# ✅ Batch 998: [1, 1, 2]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# ✅ Batch 999: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# ✅ Batch 1000: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# ✅ Batch 1001: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# ✅ Batch 1002: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# ✅ Batch 1003: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# ✅ Batch 1004: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# ✅ Batch 1005: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# ✅ Batch 1006: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# ✅ Batch 1007: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# ✅ Batch 1008: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# ✅ Batch 1009: [None, None, None]
# ✅ Batch 1010: [1, 2, 0]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# ✅ Batch 1011: [None, None, None]
# ✅ Batch 1012: [3, 2, 2]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# ✅ Batch 1013: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# ✅ Batch 1014: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
# ...
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# ✅ Batch 1108: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# ✅ Batch 1109: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# ✅ Batch 1110: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 9
# }
# ]
# ✅ Batch 1111: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# ✅ Batch 1112: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 58
# }
# ]
# ✅ Batch 1113: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# ✅ Batch 1114: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# ✅ Batch 1115: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# ✅ Batch 1116: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# ✅ Batch 1117: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# ✅ Batch 1118: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# ✅ Batch 1119: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# ✅ Batch 1120: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# ✅ Batch 1121: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 9
# }
# ]
# ✅ Batch 1122: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# ✅ Batch 1123: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 58
# }
# ]
# ✅ Batch 1124: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# ✅ Batch 1125: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# ✅ Batch 1126: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# ✅ Batch 1127: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# ✅ Batch 1128: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# ✅ Batch 1129: [None, None, None]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 1000
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# ✅ Batch 1130: [None, None, None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 19
#      17     predicted_labels.extend(batch_preds)
#      18     print(f"✅ Batch {i//batch_size + 1}: {batch_preds}")
# ---> 19     time.sleep(5)  # Delay between requests to avoid triggering RPD
#      20 except Exception as e:
#      21     print(f"❌ Error on batch {i//batch_size + 1}: {e}")
#
# KeyboardInterrupt:

# %%
# Step 7: Evaluation metrics
# Replace None with 0 in predictions
cleaned_preds = [0 if p is None else int(p) for p in predicted_labels]

# Truncate true labels to match
true_labels_eval = true_labels[:len(cleaned_preds)]

print("\nEvaluation Results:")
print("Accuracy:", accuracy_score(true_labels_eval, predicted_labels))
print("Macro F1 Score:", f1_score(true_labels_eval, predicted_labels, average='macro'))
print("Weighted F1 Score:", f1_score(true_labels_eval, predicted_labels, average='weighted'))
# Out:
# Evaluation Results:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 9
#       6 true_labels_eval = true_labels[:len(cleaned_preds)]
#       8 print("\nEvaluation Results:")
# ----> 9 print("Accuracy:", accuracy_score(true_labels_eval, predicted_labels))
#      10 print("Macro F1 Score:", f1_score(true_labels_eval, predicted_labels, average='macro'))
#      11 print("Weighted F1 Score:", f1_score(true_labels_eval, predicted_labels, average='weighted'))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:231, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     229 xp, _, device = get_namespace_and_device(y_true, y_pred, sample_weight)
#     230 # Compute accuracy for each possible representation
# --> 231 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     232 check_consistent_length(y_true, y_pred, sample_weight)
#     233 if y_type.startswith("multilabel"):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:112, in _check_targets(y_true, y_pred)
#     109     y_type = {"multiclass"}
#     111 if len(y_type) > 1:
# --> 112     raise ValueError(
#     113         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     114             type_true, type_pred
#     115         )
#     116     )
#     118 # We can't have more than one value on y_type => The set is no more needed
#     119 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of multiclass and unknown targets
